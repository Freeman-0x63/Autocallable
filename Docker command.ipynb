# %% [markdown]
# Create container
#
# docker run --name gamma-vega-rl-hedging-container -it -v ${PWD}:/app gammavegarlhedging

# %% [markdown]
# Go into an existing container
#
# docker exec -it gamma-vega-rl-hedging-container bash

# %% [markdown]
# python run.py -spread=0.005 -obj_func=var -train_sim=40000 -eval_sim=5000 -logger_prefix=batch1/TableTest/TC05/RL/var -n_step=5 -client_option="American Call","American Put" -client_style_beta=1,1 -hedge_option="American Call","American Put" -hedge_style_alpha=1,1

# %% [markdown]
# python run.py -spread=0.005 -obj_func=var -train_sim=40000 -eval_sim=5000 -logger_prefix=batch1/TableTest/TC05/RL/var -n_step=5 -client_option="American Call" -hedge_option="American Call"

# %% [markdown]
#  python greek_run.py -spread=0.005 -eval_sim=5000 -strategy=delta -logger_prefix=batch1/Table0829/TC20/Baseline/gamma -client_option="American Call" -hedge_
# option="American Call"
